# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def open_dataset(filename, sep=';'):
    data = []
    f = open(filename, 'r')
    win = []
    for i in f.readlines():
        i = i.strip()
        if i == "":
            continue
        elif i != '--':
            win.append([float(x) for x in i.split(',')])
        else:
            data.append(win)
            win = []
    return data

# %%
dataset = open_dataset('log_file.txt')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-6351436ca26f> in <module>()
# ----> 1 dataset = open_dataset('log_file.txt')
#
# <ipython-input-2-d9785da1a881> in open_dataset(filename, sep)
#       6         i = i.strip()
#       7         if i != '--':
# ----> 8             win.append([float(x) for x in i.split(',')])
#       9         else:
#      10             data.append(win)
#
# ValueError: could not convert string to float: (0

# %%
print len(dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-2fdfbd75c874> in <module>()
# ----> 1 print len(dataset)
#
# NameError: name 'dataset' is not defined

# %%
from collections import defaultdict
win = 5

fig = figure(figsize=(20,10))

ax = fig.add_subplot(1,4, 1)

s_lens = []
for p in range(20):
    ax = fig.add_subplot(5,4, p+1)
    
    clusters = defaultdict(list)
    
    for x, y in zip([int(j[0]) for j in dataset[p]], [float(j[1]) for j in dataset[p]]):
        clusters[x].append(y)
    
    lens = []
    for k, v in clusters.iteritems():
        
        var = np.var(v)
        
        lens.append(len(v))

        ax.scatter(k, np.var(v))
        ax.set_xlim((-1,10))
        ax.set_xticks(range(-1,11,2))
        ax.set_xlabel('Cluster ID')
        ax.set_ylabel('Smallest Eigen proj')
    
    s_lens.append(np.mean(lens))
    print "In plot {} mean length {}".format(p, np.mean(lens))
plt.tight_layout()
plt.show()

fig = figure(figsize=(12,3))
plt.hist(s_lens)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-54c7d055a2d5> in <module>()
#      12     clusters = defaultdict(list)
#      13
# ---> 14     for x, y in zip([int(j[0]) for j in dataset[p]], [float(j[1]) for j in dataset[p]]):
#      15         clusters[x].append(y)
#      16
#
# NameError: name 'dataset' is not defined

# %% [markdown]
# #### PLOT ALL VARS

# %%
all_vars = []
lens = []

count = 0
nclusters = 0
for p in range(len(dataset)):
    clusters = defaultdict(list)
    for x, y in zip([int(j[0]) for j in dataset[p]], [float(j[1]) for j in dataset[p]]):
        clusters[x].append(y)
    
    for k, v in clusters.iteritems():
        var = np.var(v)
        all_vars.append(var)
        lens.append(len(v))
        nclusters +=1
    
    count +=1

print "Total number of windows: {}".format(count)
print "Total number of clusters: {}".format(nclusters)
plt.plot(all_vars)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-ba15728b45e4> in <module>()
#       4 count = 0
#       5 nclusters = 0
# ----> 6 for p in range(len(dataset)):
#       7     clusters = defaultdict(list)
#       8     for x, y in zip([int(j[0]) for j in dataset[p]], [float(j[1]) for j in dataset[p]]):
#
# NameError: name 'dataset' is not defined

# %%
dataset = open_dataset('log_file.txt')
print "Dataset length: {}".format(len(dataset))
# Out:
# Dataset length: 70

# %%
from collections import defaultdict

fig = figure(figsize=(20,10))

ax = fig.add_subplot(1,4, 1)

s_lens = []

r = range(20)
for p in r:
    
    data = dataset[p]
    
    print "Plot #{}".format(p)
    
    ax = fig.add_subplot(5,4, p+1-r[0])
    
    points = defaultdict(list)
    for x,stamp,y in data:
        points[x].append([stamp,y])

    for k in points.keys():
        if len(points[k]) > 8:
            points[k] = points[k][1:]
        ax.plot([pt[0] for pt in points[k]], [pt[1] for pt in points[k]], label="Cluster #{}".format(int(k)))
        ax.legend(loc='best')
        ax.set_ylabel('angle')
        ax.set_xlabel('time')
        ax.set_title('win #{}'.format(p))
        print "Points in clusters #{}: {}".format(k,points[k])

plt.tight_layout()
plt.show()
# Out:
# Plot #0
# Points in clusters #0.0: [[0.0, 177.701], [1.0, 90.6648], [2.0, 90.2552], [3.0, 90.0184], [4.0, 90.0093], [5.0, 90.0281], [6.0, 90.0603], [7.0, 90.1157], [8.0, 90.2032]]
# Points in clusters #1.0: [[1.0, 92.0089], [2.0, 90.8437], [3.0, 90.7494], [4.0, 90.0526], [5.0, 90.1375], [6.0, 90.1502], [7.0, 90.0997], [8.0, 90.1177]]
# Points in clusters #2.0: [[1.0, 91.0962], [2.0, 91.0031], [3.0, 90.7097], [4.0, 90.2601], [5.0, 90.0574], [6.0, 90.048], [7.0, 90.0857], [8.0, 90.1572]]
# Points in clusters #3.0: [[2.0, 90.3362], [3.0, 90.0734], [4.0, 90.0432], [5.0, 90.036], [6.0, 90.0043], [7.0, 90.0994], [8.0, 90.1389]]
# Points in clusters #4.0: [[5.0, 90.3267], [6.0, 90.3797], [7.0, 91.0676], [8.0, 90.7126]]
# Plot #1
# Points in clusters #0.0: [[0.0, 180.0], [1.0, 90.3521], [2.0, 90.1904], [3.0, 90.879], [4.0, 91.3154], [5.0, 91.7714], [6.0, 92.2209], [7.0, 96.0217], [8.0, 96.3331]]
# Points in clusters #1.0: [[1.0, 91.9694], [2.0, 90.4878], [3.0, 90.0472], [4.0, 90.0186], [5.0, 90.0152], [6.0, 90.2981], [7.0, 90.4], [8.0, 90.4774]]
# Points in clusters #2.0: [[1.0, 91.4142], [2.0, 90.079], [3.0, 90.0525], [4.0, 90.2157], [5.0, 90.0769], [6.0, 90.2807], [7.0, 90.3097], [8.0, 90.3142]]
# Points in clusters #3.0: [[2.0, 90.0097], [3.0, 90.0925], [4.0, 90.0395], [5.0, 90.2027], [6.0, 90.0687], [7.0, 90.0391], [8.0, 90.0566]]
# Points in clusters #4.0: [[5.0, 90.0844], [6.0, 90.3628], [7.0, 90.4029], [8.0, 90.5616]]
# Points in clusters #5.0: [[8.0, 102.405]]
# Plot #2
# Points in clusters #0.0: [[0.0, 178.51], [1.0, 113.424], [2.0, 114.925], [3.0, 121.166], [4.0, 122.47], [5.0, 115.107], [6.0, 108.127], [7.0, 103.565], [8.0, 105.295]]
# Points in clusters #1.0: [[1.0, 90.5603], [2.0, 90.1799], [3.0, 90.24], [4.0, 90.2811], [5.0, 90.3205], [6.0, 90.2215], [7.0, 90.1627], [8.0, 90.1047]]
# Points in clusters #2.0: [[1.0, 90.5592], [2.0, 90.4876], [3.0, 90.4697], [4.0, 90.0432], [5.0, 90.1367], [6.0, 90.0539], [7.0, 90.0539], [8.0, 90.0143]]
# Points in clusters #2.0: [[0.0, 91.1154], [1.0, 90.1743], [2.0, 90.194], [3.0, 93.2737], [4.0, 95.0514], [5.0, 95.731], [6.0, 96.2824], [7.0, 96.6973]]
# Points in clusters #3.0: [[1.0, 92.5558], [2.0, 92.5558], [3.0, 91.6573], [4.0, 93.5882], [5.0, 95.1241], [6.0, 95.6976], [7.0, 95.7711]]
# Points in clusters #4.0: [[1.0, 95.0811], [2.0, 91.8421], [3.0, 93.9719], [4.0, 93.9719], [5.0, 96.7958], [6.0, 96.7958], [7.0, 95.5655]]
# Points in clusters #5.0: [[2.0, 96.5443], [3.0, 97.5744], [4.0, 97.5744], [5.0, 95.2641], [6.0, 94.7293], [7.0, 94.7293]]
# Points in clusters #6.0: [[7.0, 124.854]]
# Plot #8
# Points in clusters #0.0: [[0.0, 180.0], [1.0, 178.369], [2.0, 144.323], [3.0, 100.371], [4.0, 100.384], [5.0, 104.109], [6.0, 106.681], [7.0, 106.681], [8.0, 106.681]]
# Points in clusters #1.0: [[0.0, 180.0]]
# Points in clusters #2.0: [[1.0, 122.188], [2.0, 122.188], [3.0, 98.3575], [4.0, 96.1033], [5.0, 92.9032], [6.0, 92.7717], [7.0, 93.2378], [8.0, 93.9734]]
# Points in clusters #3.0: [[1.0, 121.675], [2.0, 108.364], [3.0, 100.407], [4.0, 94.8396], [5.0, 92.773], [6.0, 92.3897], [7.0, 91.5254], [8.0, 90.8781]]
# Points in clusters #4.0: [[2.0, 102.286], [3.0, 97.4936], [4.0, 95.3609], [5.0, 95.221], [6.0, 94.5511], [7.0, 93.9032], [8.0, 93.6458]]
# Points in clusters #5.0: [[6.0, 90.8667], [7.0, 110.748], [8.0, 109.216]]
# Plot #9
# Points in clusters #0.0: [[0.0, 180.0], [1.0, 103.453], [2.0, 108.543], [3.0, 115.835], [4.0, 109.835], [5.0, 103.175], [6.0, 100.515], [7.0, 100.515], [8.0, 100.515]]
# Points in clusters #1.0: [[1.0, 99.7722], [2.0, 96.08], [3.0, 95.4562], [4.0, 92.3895], [5.0, 90.2502], [6.0, 92.0594], [7.0, 92.1115], [8.0, 91.741]]
# Points in clusters #2.0: [[2.0, 129.637], [3.0, 125.561], [4.0, 127.734], [5.0, 103.682], [6.0, 95.4978], [7.0, 92.5945], [8.0, 91.3011]]
# Points in clusters #3.0: [[3.0, 104.46], [4.0, 101.16], [5.0, 92.3553], [6.0, 91.2561], [7.0, 90.6978], [8.0, 90.6884]]
# Plot #10
# Points in clusters #0.0: [[0.0, 90.511], [1.0, 90.511], [2.0, 93.172], [3.0, 91.8362], [4.0, 90.9674], [5.0, 90.4908], [6.0, 90.0201], [7.0, 90.0941]]
# Points in clusters #1.0: [[1.0, 98.2133], [2.0, 96.582], [3.0, 95.3117], [4.0, 94.5257], [5.0, 94.1992], [6.0, 94.1677], [7.0, 93.0811]]
# Points in clusters #2.0: [[1.0, 180.0], [2.0, 93.6053], [3.0, 93.6053], [4.0, 93.6053], [5.0, 93.6053], [6.0, 93.6053], [7.0, 93.6053]]
# Points in clusters #3.0: [[1.0, 99.2145], [2.0, 96.2989], [3.0, 95.7316], [4.0, 95.2927], [5.0, 95.2976], [6.0, 95.29], [7.0, 95.0832]]
# Points in clusters #4.0: [[5.0, 96.9483], [6.0, 93.7709], [7.0, 91.5533]]
# Points in clusters #5.0: [[7.0, 180.0]]
# Plot #11
# Points in clusters #0.0: [[0.0, 180.0], [1.0,
# Points in clusters #4.0: [[2.0, 99.1065], [3.0, 90.4659], [4.0, 94.9488], [5.0, 95.3882], [6.0, 94.1184], [7.0, 93.9697], [8.0, 93.0345]]
# Points in clusters #5.0: [[2.0, 91.7273], [3.0, 91.4551], [4.0, 90.6046], [5.0, 90.6046], [6.0, 90.6046], [7.0, 90.6046], [8.0, 90.6046]]
# Points in clusters #6.0: [[2.0, 121.487], [3.0, 119.995], [4.0, 120.653], [5.0, 121.531], [6.0, 119.073], [7.0, 117.067], [8.0, 115.78]]
# Plot #14
# Points in clusters #0.0: [[0.0, 178.611], [1.0, 159.382], [2.0, 94.5663], [3.0, 103.385], [4.0, 102.787], [5.0, 100.682], [6.0, 95.9245], [7.0, 90.2102], [8.0, 91.1828]]
# Points in clusters #1.0: [[2.0, 95.1591], [3.0, 100.259], [4.0, 103.57], [5.0, 105.621], [6.0, 95.7968], [7.0, 92.4042], [8.0, 92.7618]]
# Points in clusters #2.0: [[2.0, 92.0128], [3.0, 91.9284], [4.0, 92.3409], [5.0, 92.4878], [6.0, 92.1226], [7.0, 91.1631], [8.0, 90.6595]]
# Points in clusters #3.0: [[2.0, 91.4059], [3.0, 91.7161], [4.0, 90.2221], [5.0, 91.5652], [6.0, 91.5408], [7.0, 91.672], [8.0, 91.2434]]
# Points in clusters #4.0: [[4.0, 91.8747], [5.0, 96.4261], [6.0, 96.4261], [7.0, 102.51], [8.0, 102.51]]
# Plot #15
# Points in clusters #0.0: [[0.0, 95.2687], [1.0, 91.9093], [2.0, 92.4205], [3.0, 91.5931], [4.0, 92.0009], [5.0, 91.8731], [6.0, 91.6531], [7.0, 91.4731]]
# Points in clusters #1.0: [[0.0, 101.701], [1.0, 92.9804], [2.0, 92.7622], [3.0, 90.9022], [4.0, 91.5584], [5.0, 91.5369], [6.0, 91.9976], [7.0, 91.7619]]
# Points in clusters #2.0: [[1.0, 91.5623], [2.0, 90.0901], [3.0, 90.1856], [4.0, 90.1638], [5.0, 90.2653], [6.0, 90.1669], [7.0, 90.0259]]
# Points in clusters #3.0: [[1.0, 90.812], [2.0, 90.3243], [3.0, 90.6244], [4.0, 90.2461], [5.0, 91.3699], [6.0, 91.8526], [7.0, 92.0398]]
# Plot #16
# Points in clusters #0.0: [[0.0, 90.1107], [1.0, 90.3565], [2.0, 90.6503], [3.0, 90.6954], [4.0, 90.7485], [5.0, 90.544], [6.0, 90.56], [7.0, 90.5605]]
# Points in clusters #1.0: [[0.0, 104.354], [1.0, 98.2477], [2.0, 90.1979], [3.0, 90.2686], [4.0, 90.8737], [5.0, 90.1398], [6.0, 93.7606], [7.0, 96.8075]]
# Points in clusters #2.0: [[0.0, 91.8287], [1.0, 90.0784], [2.0, 90.4607], [3.0, 90.0136], [4.0, 90.5556], [5.0, 90.7959], [6.0, 90.3783], [7.0, 90.5907]]
# Points in clusters #3.0: [[1.0, 90.536], [2.0, 90.4592], [3.0, 91.3029], [4.0, 90.8997], [5.0, 90.7101], [6.0, 90.8844], [7.0, 90.7413]]
# Points in clusters #4.0: [[5.0, 90.302], [6.0, 90.8868], [7.0, 91.6086]]
# Plot #17
# Points in clusters #0.0: [[0.0, 180.0], [1.0, 90.4492], [2.0, 90.2602], [3.0, 90.327], [4.0, 91.9557], [5.0, 94.6253]]
# Points in clusters #1.0: [[0.0, 180.0], [1.0, 161.051], [2.0, 153.195], [3.0, 150.157], [4.0, 150.157], [5.0, 150.157], [6.0, 99.2333], [7.0, 99.5594], [8.0, 98.3517]]
# Points in clusters #2.0: [[1.0, 90.981], [2.0, 96.4582], [3.0, 96.4582], [4.0, 96.4582], [5.0, 96.4582], [6.0, 104.017], [7.0, 104.017], [8.0, 104.017]]
# Points in clusters #3.0: [[1.0, 114.482], [2.0, 123.503], [3.0, 106.515], [4.0, 106.515], [5.0, 107.724], [6.0, 108.992], [7.0, 109.908], [8.0, 108.052]]
# Points in clusters #4.0: [[2.0, 133.581], [3.0, 113.786], [4.0, 112.169], [5.0, 114.998], [6.0, 113.611], [7.0, 113.001], [8.0, 111.754]]
# Points in clusters #5.0: [[5.0, 122.094], [6.0, 122.094], [7.0, 122.094], [8.0, 122.094]]
# Plot #18
# Points in clusters #0.0: [[0.0, 180.0], [1.0, 174.413], [2.0, 108.001], [3.0, 94.7891], [4.0, 90.972], [5.0, 90.2676], [6.0, 91.4443], [7.0, 91.1862], [8.0, 91.1862]]
# Points in clusters #1.0: [[1.0, 132.372], [2.0, 122.236], [3.0, 122.236], [4.0, 91.5979], [5.0, 92.6138], [6.0, 92.6138], [7.0, 93.3605], [8.0, 93.3605]]
# Points in clusters #2.0: [[1.0, 111.779], [2.0, 104.514], [3.0, 99.3858], [4.0, 94.5806], [5.0, 91.2482], [6.0, 91.2482], [7.0, 94.3308], [8.0, 94.3308]]
# Points in clusters #3.0: [[2.0, 121.554], [3.0, 116.89], [4.0, 95.4486], [5.0, 91.4449], [6.0, 91.4449], [7.0, 91.4449], [8.0, 91.4449]]
# Points in clusters #4.0: [[4.0, 93.6457], [5.0, 93.6457], [6.0, 93.6457], [7.0, 93.6457], [8.0, 93.6457]]
# Plot #19
# Points in clusters #0.0: [[0.0, 177.899], [1.0, 178.045], [2.0, 109.204], [3.0, 90.7632], [4.0, 93.2272], [5.0, 96.0728], [6.0, 92.8989], [7.0, 93.0659], [8.0, 94.4959]]
# Points in clusters #1.0: [[2.0, 95.5426], [3.0, 94.5604], [4.0, 94.5604], [5.0, 94.5604], [6.0, 94.5604], [7.0, 94.5604], [8.0, 94.5604]]
# Points in clusters #2.0: [[3.0, 92.3043], [4.0, 92.3043], [5.0, 95.3186], [6.0, 97.8645], [7.0, 97.5445], [8.0, 114.407]]
# Points in clusters #3.0: [[4.0, 91.4195], [5.0, 90.2707], [6.0, 91.6329], [7.0, 92.0906], [8.0, 92.0906]]
# Points in clusters #4.0: [[6.0, 90.2792], [7.0, 92.6318], [8.0, 101.466]]
